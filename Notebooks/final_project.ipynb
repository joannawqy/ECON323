# %% [markdown]
# <a href="https://colab.research.google.com/github/joannawqy/ECON323/blob/main/Notebooks/final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Packages

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## education completion rate

# %%
#pip install openpyxl --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 3.2 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
edu_comp = pd.read_excel('/Users/mac/Desktop/ECON323/ECON323/Data/popratio_educompletion.xlsx')
edu_comp.head()
# Out:
#    Goal  Target Indicator   SeriesCode  \
# 0     4     4.1     4.1.2  SE_TOT_CPLR
# 1     4     4.1     4.1.2  SE_TOT_CPLR
# 2     4     4.1     4.1.2  SE_TOT_CPLR
# 3     4     4.1     4.1.2  SE_TOT_CPLR
# 4     4     4.1     4.1.2  SE_TOT_CPLR
#
#                                    SeriesDescription  GeoAreaCode  \
# 0  Completion rate, by sex, location, wealth quin...            4
# 1  Completion rate, by sex, location, wealth quin...            4
# 2  Completion rate, by sex, location, wealth quin...            4
# 3  Completion rate, by sex, location, wealth quin...            4
# 4  Completion rate, by sex, location, wealth quin...            4
#
#    GeoAreaName  TimePeriod  Value  Time_Detail  ...  Age  Education level  \
# 0  Afghanistan        2016     43         2016  ...  NaN           LOWSEC
# 1  Afghanistan        2016     41         2016  ...  NaN           UPPSEC
# 2  Afghanistan        2016     30         2016  ...  NaN           LOWSEC
# ...

# %% [markdown]
# Get GeoAreaName, TimePeriod, Value, Educationlevel, Location, Quantile, Sex

# %%
edu_comp = edu_comp[['GeoAreaName', 'TimePeriod','Value','Education level','Location', 'Quantile', 'Sex']]

# %%
edu_comp.rename(columns={'Value': 'edu_comp_ratio'}, inplace=True)
# Out:
# /var/folders/03/lsf9g8v9479dwcnljvyfxdj40000gn/T/ipykernel_2553/1026454497.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edu_comp.rename(columns={'Value': 'edu_comp_ratio'}, inplace=True)

# %%
edu_comp
# Out:
#        GeoAreaName  TimePeriod  edu_comp_ratio Education level Location  \
# 0      Afghanistan        2016              43          LOWSEC  ALLAREA
# 1      Afghanistan        2016              41          UPPSEC  ALLAREA
# 2      Afghanistan        2016              30          LOWSEC  ALLAREA
# 3      Afghanistan        2016              55          LOWSEC  ALLAREA
# 4      Afghanistan        2016              45          PRIMAR  ALLAREA
# ...            ...         ...             ...             ...      ...
# 35408       Zambia        2020              45          LOWSEC  ALLAREA
# 35409       Zambia        2020              48          LOWSEC  ALLAREA
# 35410       Zambia        2020              28          UPPSEC  ALLAREA
# 35411       Zambia        2020              65          PRIMAR  ALLAREA
# 35412       Zambia        2020              74          PRIMAR  ALLAREA
#
#       Quantile      Sex
# 0           _T  BOTHSEX
# 1           _T     MALE
# 2           _T   FEMALE
# ...
